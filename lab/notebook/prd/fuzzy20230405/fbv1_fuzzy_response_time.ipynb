# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import sys
import math
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import model_selection
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV,ElasticNetCV
from pyentrp import entropy as pyent
import EntropyHub as EH
import neurokit2 as nk
import random
import sampen
import requests
import io
from pprint import pprint
import os
from sklearn import preprocessing
from influxdb_client import InfluxDBClient, Point
from influxdb_client.client.write_api import SYNCHRONOUS
from influxdb_client.client.flux_table import FluxTable
from datetime import datetime, timedelta
from typing import List
import itertools
from datetime import datetime
from datetime import timedelta
import itertools
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# %%
c_01 = pd.read_csv("fbv1_hpq.log", names=["date", "size"])
c_01
# Out:
#                           date  size
# 0    2023-05-04T13:17:27+00:00     8
# 1    2023-05-04T13:17:28+00:00     8
# 2    2023-05-04T13:17:29+00:00     8
# 3    2023-05-04T13:17:30+00:00     8
# 4    2023-05-04T13:17:32+00:00     8
# ..                         ...   ...
# 653  2023-05-04T13:29:36+00:00    16
# 654  2023-05-04T13:29:37+00:00    16
# 655  2023-05-04T13:29:39+00:00    16
# 656  2023-05-04T13:29:40+00:00    16
# 657  2023-05-04T13:29:41+00:00    16
#
# [658 rows x 2 columns]

# %%
c_01["size"].sum()
# Out:
# 8921

# %%
def parse(path: str) -> pd.DataFrame:
    # CSVから読み取る
    try:
        df = pd.read_csv(path,  delimiter='\t', header=None, names=[ 'c{0:02d}'.format(i) for i in range(10) ])
    except Exception as e:
        raise(e)
    df_target = df.to_numpy()

    # いい感じに整形
    requests = pd.DataFrame([{"date": datetime.fromtimestamp(float(d[4])/1000), "status": d[6], "count": 1} for d in df_target if (d[0] == "REQUEST" and not math.isnan(float(d[4])) )])
    if len(requests) == 0:
        return pd.DataFrame([])

    # 1秒ごとにサマる
    grouped1 = requests.groupby([pd.Grouper(key=("status")),pd.Grouper(key=("date"), freq="S")]).sum().reset_index()

    # 全部同じ数は困るので乱数を入れておく
    for x in range(len(grouped1)):
        grouped1.iat[x, 2] += np.random.rand() * sys.float_info.epsilon

    return grouped1

# %%
df = pd.read_csv("./fbv1+simulation.log",  delimiter='\t', header=None, names=[ 'c{0:02d}'.format(i) for i in range(10) ])
# Out:
# /var/folders/zk/cf948rq56631k5dgzn62fkjm0000gn/T/ipykernel_57048/3674241417.py:1: DtypeWarning: Columns (2,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./fbv1+simulation.log",  delimiter='\t', header=None, names=[ 'c{0:02d}'.format(i) for i in range(10) ])

# %%
df_target = df.to_numpy()
requests = pd.DataFrame([{"start": datetime.fromtimestamp(float(d[4])/1000), "end": datetime.fromtimestamp(float(d[5])/1000), "status": d[6], "count": 1} for d in df_target if (d[0] == "REQUEST" and not math.isnan(float(d[4])) and not math.isnan(float(d[5])) )])

# %%
requests["duration"] = ((requests["end"] - requests["start"]) / np.timedelta64(1,'ms')).astype(int)
requests
# Out:
#                          start                     end status  count  duration
# 0      2023-05-04 22:17:56.026 2023-05-04 22:17:56.093     OK      1        67
# 1      2023-05-04 22:17:55.993 2023-05-04 22:17:56.097     OK      1       104
# 2      2023-05-04 22:17:55.960 2023-05-04 22:17:56.065     OK      1       105
# 3      2023-05-04 22:17:55.955 2023-05-04 22:17:56.002     OK      1        47
# 4      2023-05-04 22:17:55.960 2023-05-04 22:17:56.118     OK      1       158
# ...                        ...                     ...    ...    ...       ...
# 263776 2023-05-04 22:29:25.891 2023-05-04 22:29:25.911     OK      1        20
# 263777 2023-05-04 22:29:25.901 2023-05-04 22:29:25.912     OK      1        11
# 263778 2023-05-04 22:29:25.901 2023-05-04 22:29:25.913     OK      1        12
# 263779 2023-05-04 22:29:25.901 2023-05-04 22:29:25.915     OK      1        14
# 263780 2023-05-04 22:29:25.901 2023-05-04 22:29:25.916     OK      1        15
#
# [263781 rows x 5 columns]

# %%
grouped1 = requests.groupby([pd.Grouper(key=("end"), freq="S"), pd.Grouper(key=("duration"))]).mean().reset_index()
# Out:
# /var/folders/zk/cf948rq56631k5dgzn62fkjm0000gn/T/ipykernel_57048/1014284209.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped1 = requests.groupby([pd.Grouper(key=("end"), freq="S"), pd.Grouper(key=("duration"))]).mean().reset_index()

# %%
grouped1
# Out:
#                       end  duration  count
# 0     2023-05-04 22:17:56         6    1.0
# 1     2023-05-04 22:17:56         7    1.0
# 2     2023-05-04 22:17:56         8    1.0
# 3     2023-05-04 22:17:56         9    1.0
# 4     2023-05-04 22:17:56        10    1.0
# ...                   ...       ...    ...
# 27870 2023-05-04 22:29:25        30    1.0
# 27871 2023-05-04 22:29:25        31    1.0
# 27872 2023-05-04 22:29:25        33    1.0
# 27873 2023-05-04 22:29:25        35    1.0
# 27874 2023-05-04 22:29:25        36    1.0
#
# [27875 rows x 3 columns]

# %%
plt.plot(grouped1['end'], grouped1['duration'])

# %%
def parse(path: str) -> pd.DataFrame:
    # CSVから読み取る
    try:
        df = pd.read_csv(path,  delimiter='\t', header=None, names=[ 'c{0:02d}'.format(i) for i in range(10) ])
    except Exception as e:
        raise(e)
    df_target = df.to_numpy()

    # いい感じに整形
    requests = pd.DataFrame([{"date": datetime.fromtimestamp(float(d[4])/1000), "status": d[6], "count": 1} for d in df_target if (d[0] == "REQUEST" and not math.isnan(float(d[4])) )])
    if len(requests) == 0:
        return pd.DataFrame([])

    # 1秒ごとにサマる
    grouped1 = requests.groupby([pd.Grouper(key=("status")),pd.Grouper(key=("date"), freq="S")]).sum().reset_index()

    # 全部同じ数は困るので乱数を入れておく
    for x in range(len(grouped1)):
        grouped1.iat[x, 2] += np.random.rand() * sys.float_info.epsilon

    return grouped1

# %%
df_01 = parse("./fbv1+simulation.log")
# Out:
# /var/folders/zk/cf948rq56631k5dgzn62fkjm0000gn/T/ipykernel_57048/600845077.py:4: DtypeWarning: Columns (2,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path,  delimiter='\t', header=None, names=[ 'c{0:02d}'.format(i) for i in range(10) ])

# %%
df_01_date = df_01["date"]
df_01_count = df_01["count"]
replaced_df_01_date = [(d - df_01_date[0]).seconds for d in df_01_date]
plt.plot(replaced_df_01_date, df_01_count)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
df_01_date = df_01["date"][20:]
df_01_count = df_01["count"][20:]
# ln1=ax1.plot(df_01_date, df_01_count, 'C0', zorder=0.1, label='workload')
df_02_date = grouped1['end'][20:]
ln1=ax1.plot([(d - df_02_date[20]).seconds for d in df_02_date], grouped1['duration'][20:], color="orange", zorder=0.1, label='response time')
ax2 = ax1.twinx()

# ln2=ax2.plot(grouped1['end'][20:],grouped1['duration'][20:],'C1', zorder=0.02, label='response time')
ln2=ax2.plot([(d - df_01_date[20]).seconds for d in df_01_date], df_01_count, color="red",  zorder=0.02, linestyle = "dashed", label='workload')
ax1.set_xlabel(xlabel="time interval")
ax2.set_ylabel(ylabel="request per sec")
ax1.set_ylabel(ylabel="mean response time")

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
ax1.legend(h1+h2, l1+l2, loc='upper right')

ax1.grid(True)
plt.savefig("fuzzy_fbv1_20230505_responsetime_02.png")

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.ghq/github.com/nnao45/jaist-my-jupyter/.venv/lib/python3.8/site-packages/pandas/core/indexes/range.py:391, in RangeIndex.get_loc(self, key, method, tolerance)
#     390 try:
# --> 391     return self._range.index(new_key)
#     392 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 [(d - df_01_date[0]).seconds for d in df_01_date]
#
# Cell In[92], line 1, in <listcomp>(.0)
# ----> 1 [(d - df_01_date[0]).seconds for d in df_01_date]
#
# File ~/.ghq/github.com/nnao45/jaist-my-jupyter/.venv/lib/python3.8/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/.ghq/github.com/nnao45/jaist-my-jupyter/.venv/lib/python3.8/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/.ghq/github.com/nnao45/jaist-my-jupyter/.venv/lib/python3.8/site-packages/pandas/core/indexes/range.py:393, in RangeIndex.get_loc(self, key, method, tolerance)
#     391         return self._range.index(new_key)
#     392     except ValueError as err:
# --> 393         raise KeyError(key) from err
#     394 self._check_indexing_error(key)
#     395 raise KeyError(key)
#
# KeyError: 0
