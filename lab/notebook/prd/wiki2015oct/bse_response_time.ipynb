# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import sys
import math
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import model_selection
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV,ElasticNetCV
from pyentrp import entropy as pyent
import EntropyHub as EH
import neurokit2 as nk
import random
import sampen
import requests
import io
from pprint import pprint
import os
from sklearn import preprocessing
from influxdb_client import InfluxDBClient, Point
from influxdb_client.client.write_api import SYNCHRONOUS
from influxdb_client.client.flux_table import FluxTable
from datetime import datetime, timedelta
from typing import List
import itertools
from datetime import datetime
import itertools
from sklearn.tree import DecisionTreeRegressor

# %%
c_01 = pd.read_csv("hpq_20221116144838.log", names=["date", "size"])
c_01
# Out:
#                            date  size
# 0     2022-11-16T14:49:55+00:00    14
# 1     2022-11-16T14:49:56+00:00    14
# 2     2022-11-16T14:49:57+00:00    14
# 3     2022-11-16T14:49:58+00:00    14
# 4     2022-11-16T14:50:00+00:00    14
# ...                         ...   ...
# 1022  2022-11-16T15:09:20+00:00    13
# 1023  2022-11-16T15:09:21+00:00    13
# 1024  2022-11-16T15:09:22+00:00    13
# 1025  2022-11-16T15:09:23+00:00    13
# 1026  2022-11-16T15:09:24+00:00    13
#
# [1027 rows x 2 columns]

# %%
def parse(path: str) -> pd.DataFrame:
    # CSVから読み取る
    try:
        df = pd.read_csv(path,  delimiter='\t', header=None, names=[ 'c{0:02d}'.format(i) for i in range(10) ])
    except Exception as e:
        raise(e)
    df_target = df.to_numpy()

    # いい感じに整形
    requests = pd.DataFrame([{"date": datetime.fromtimestamp(float(d[4])/1000), "status": d[6], "count": 1} for d in df_target if (d[0] == "REQUEST" and not math.isnan(float(d[4])) )])
    if len(requests) == 0:
        return pd.DataFrame([])

    # 1秒ごとにサマる
    grouped1 = requests.groupby([pd.Grouper(key=("status")),pd.Grouper(key=("date"), freq="S")]).sum().reset_index()

    # 全部同じ数は困るので乱数を入れておく
    for x in range(len(grouped1)):
        grouped1.iat[x, 2] += np.random.rand() * sys.float_info.epsilon

    return grouped1

# %%
df_01 = parse("./simulation_bse.log")
# Out:
# /var/folders/zk/cf948rq56631k5dgzn62fkjm0000gn/T/ipykernel_86939/600845077.py:4: DtypeWarning: Columns (2,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path,  delimiter='\t', header=None, names=[ 'c{0:02d}'.format(i) for i in range(10) ])

# %%
df = pd.read_csv("./simulation_bse.log",  delimiter='\t', header=None, names=[ 'c{0:02d}'.format(i) for i in range(10) ])
# Out:
# /var/folders/zk/cf948rq56631k5dgzn62fkjm0000gn/T/ipykernel_86939/1173206437.py:1: DtypeWarning: Columns (2,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./simulation_bse.log",  delimiter='\t', header=None, names=[ 'c{0:02d}'.format(i) for i in range(10) ])

# %%
df_target = df.to_numpy()
requests = pd.DataFrame([{"start": datetime.fromtimestamp(float(d[4])/1000), "end": datetime.fromtimestamp(float(d[5])/1000), "status": d[6], "count": 1} for d in df_target if (d[0] == "REQUEST" and not math.isnan(float(d[4])) and not math.isnan(float(d[5])) )])

# %%
requests["duration"] = ((requests["end"] - requests["start"]) / np.timedelta64(1,'ms')).astype(int)
requests
# Out:
#                          start                     end status  count  duration
# 0      2022-11-16 23:49:54.327 2022-11-16 23:49:54.479     OK      1       152
# 1      2022-11-16 23:49:54.328 2022-11-16 23:49:54.633     OK      1       305
# 2      2022-11-16 23:49:54.353 2022-11-16 23:49:54.521     OK      1       168
# 3      2022-11-16 23:49:54.328 2022-11-16 23:49:54.532     OK      1       204
# 4      2022-11-16 23:49:54.333 2022-11-16 23:49:54.643     OK      1       310
# ...                        ...                     ...    ...    ...       ...
# 642628 2022-11-17 00:09:24.248 2022-11-17 00:09:24.261     OK      1        13
# 642629 2022-11-17 00:09:24.248 2022-11-17 00:09:24.263     OK      1        15
# 642630 2022-11-17 00:09:24.258 2022-11-17 00:09:24.264     OK      1         6
# 642631 2022-11-17 00:09:24.248 2022-11-17 00:09:24.264     OK      1        16
# 642632 2022-11-17 00:09:24.248 2022-11-17 00:09:24.265     OK      1        17
#
# [642633 rows x 5 columns]

# %%
grouped1 = requests.groupby([pd.Grouper(key=("end"), freq="S"), pd.Grouper(key=("duration"))]).mean().reset_index()
# Out:
# /var/folders/zk/cf948rq56631k5dgzn62fkjm0000gn/T/ipykernel_86939/1014284209.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped1 = requests.groupby([pd.Grouper(key=("end"), freq="S"), pd.Grouper(key=("duration"))]).mean().reset_index()

# %%
grouped1
# Out:
#                       end  duration  count
# 0     2022-11-16 23:49:54       152    1.0
# 1     2022-11-16 23:49:54       168    1.0
# 2     2022-11-16 23:49:54       181    1.0
# 3     2022-11-16 23:49:54       197    1.0
# 4     2022-11-16 23:49:54       204    1.0
# ...                   ...       ...    ...
# 63070 2022-11-17 00:09:24        23    1.0
# 63071 2022-11-17 00:09:24        24    1.0
# 63072 2022-11-17 00:09:24        25    1.0
# 63073 2022-11-17 00:09:24        29    1.0
# 63074 2022-11-17 00:09:24        30    1.0
#
# [63075 rows x 3 columns]

# %%
plt.plot(grouped1['end'], grouped1['duration'])

# %%
def parse(path: str) -> pd.DataFrame:
    # CSVから読み取る
    try:
        df = pd.read_csv(path,  delimiter='\t', header=None, names=[ 'c{0:02d}'.format(i) for i in range(10) ])
    except Exception as e:
        raise(e)
    df_target = df.to_numpy()

    # いい感じに整形
    requests = pd.DataFrame([{"date": datetime.fromtimestamp(float(d[4])/1000), "count": 1} for d in df_target if (d[0] == "REQUEST" and not math.isnan(float(d[4])) )])
    if len(requests) == 0:
        return pd.DataFrame([])

    # 1秒ごとにサマる
    grouped1 = requests.groupby([pd.Grouper(key=("date"), freq="S")]).sum().reset_index()

    # 全部同じ数は困るので乱数を入れておく
    for x in range(len(grouped1)):
        grouped1.iat[x, 1] += np.random.rand() * sys.float_info.epsilon

    return grouped1

# %%
df_01 = parse("./simulation_bse.log")
# Out:
# /var/folders/zk/cf948rq56631k5dgzn62fkjm0000gn/T/ipykernel_86939/3059051602.py:4: DtypeWarning: Columns (2,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path,  delimiter='\t', header=None, names=[ 'c{0:02d}'.format(i) for i in range(10) ])

# %%
df_01_date = df_01["date"]
df_01_count = df_01["count"]
plt.plot(df_01_date, df_01_count)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
df_01_date = df_01["date"][20:]
df_01_count = df_01["count"][20:]
# ln1=ax1.plot(df_01_date, df_01_count, 'C0', zorder=0.1, label='workload')
df_02_date = grouped1['end'][20:]
ln1=ax1.plot([(d - df_02_date[20]).seconds for d in df_02_date], grouped1['duration'][20:], color="orange",  zorder=0.1, label='response time')
ax2 = ax1.twinx()

# ln2=ax2.plot(grouped1['end'][20:],grouped1['duration'][20:],'C1', zorder=0.02, label='response time')
ln2=ax2.plot([(d - df_01_date[20]).seconds for d in df_01_date], df_01_count, color="red",  zorder=0.02,  linestyle = "dashed", label='workload')
ax1.set_xlabel(xlabel="time interval")
ax2.set_ylabel(ylabel="request per sec")
ax1.set_ylabel(ylabel="mean response time")

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
ax1.legend(h1+h2, l1+l2, loc='upper right')


ax1.grid(True)
plt.savefig("wiki15_response_time_bse_02.png")
