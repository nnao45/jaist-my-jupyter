# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import sys
import math
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import model_selection
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV,ElasticNetCV
from pyentrp import entropy as pyent
import EntropyHub as EH
import neurokit2 as nk
import random
import sampen
import requests
import io
from pprint import pprint
import os
from sklearn import preprocessing
from influxdb_client import InfluxDBClient, Point
from influxdb_client.client.write_api import SYNCHRONOUS
from influxdb_client.client.flux_table import FluxTable
from datetime import datetime, timedelta
from typing import List
import itertools
from datetime import datetime
import itertools

# %%
pred_01 = pd.read_csv("pred_20221028161359.log", names=["index", "date", "fuzzy", "sample", "pairwise",  "trend", "burst_mode", "entropy_mode", "pred_traffic", "pred_container", "max_cpu_usage"])
pred_01
# Out:
#     index                        date     fuzzy    sample  pairwise  \
# 0       0  2022-10-28T16:14:00.053120  1.959083       inf -0.257474
# 1       0  2022-10-28T16:14:15.540205  1.215506  1.504077 -0.830278
# 2       0  2022-10-28T16:14:30.080990  0.852753  1.526056 -0.931850
# 3       0  2022-10-28T16:14:45.386902  0.752690  1.098612 -0.956864
# 4       0  2022-10-28T16:15:00.317686  0.621394  1.029619 -0.971986
# 5       0  2022-10-28T16:15:15.498564  0.571210  1.105127 -0.973220
# 6       0  2022-10-28T16:15:30.341938  0.597269  0.963067 -0.959494
# 7       0  2022-10-28T16:15:45.532180  0.688282  1.049822 -0.923400
# 8       0  2022-10-28T16:16:00.373906  0.893289  1.420196 -0.863080
# 9       0  2022-10-28T16:16:15.464280  1.148243  1.497520 -0.788342
# 10      0  2022-10-28T16:16:30.708880  1.399469  2.043074 -0.479637
# 11      0  2022-10-28T16:16:45.741278  1.493751  2.197225  0.113852
# 12      0  2022-10-28T16:17:00.588035  1.278653  1.977163  0.626468
# ...

# %%
def parse(path: str) -> pd.DataFrame:
    # CSVから読み取る
    try:
        df = pd.read_csv(path,  delimiter='\t', header=None, names=[ 'c{0:02d}'.format(i) for i in range(10) ])
    except Exception as e:
        raise(e)
    df_target = df.to_numpy()

    # いい感じに整形
    requests = pd.DataFrame([{"date": datetime.fromtimestamp(float(d[4])/1000), "status": d[6], "count": 1} for d in df_target if (d[0] == "REQUEST" and not math.isnan(float(d[4])) )])
    if len(requests) == 0:
        return pd.DataFrame([])

    # 1秒ごとにサマる
    grouped1 = requests.groupby([pd.Grouper(key=("status")),pd.Grouper(key=("date"), freq="S")]).sum().reset_index()

    # 全部同じ数は困るので乱数を入れておく
    for x in range(len(grouped1)):
        grouped1.iat[x, 2] += np.random.rand() * sys.float_info.epsilon

    return grouped1

# %%
simulation_log_01 = parse("simulation_01.log")
simulation_log_date_01 = simulation_log_01["date"]
simulation_log_count_01 = simulation_log_01["count"]
# Out:
# /var/folders/zk/cf948rq56631k5dgzn62fkjm0000gn/T/ipykernel_11473/1581826677.py:4: DtypeWarning: Columns (2,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path,  delimiter='\t', header=None, names=[ 'c{0:02d}'.format(i) for i in range(10) ])

# %%
plt.plot(simulation_log_date_01, simulation_log_count_01)

# %%
plt.plot(simulation_log_date_01[20:], simulation_log_count_01[20:])

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 4))
ln1 = axes[0].plot(simulation_log_date_01, simulation_log_count_01,label='baseline')

ax1 = axes[0].twinx()
ln2 = ax1.plot([datetime.fromisoformat(date_str) + timedelta(hours=9) for date_str in  pred_01["date"]], pred_01["pred_container"], color='green', label="cluster_size")

h1, l1 = axes[0].get_legend_handles_labels()
h2, l2 = ax1.get_legend_handles_labels()
axes[0].legend(h1+h2, l1+l2, loc='upper left')

axes[0].grid(True)

# %%
simulation_log_02 = parse("simulation_02.log")
simulation_log_date_02 = simulation_log_02["date"]
simulation_log_count_02 = simulation_log_02["count"]
# Out:
# /var/folders/zk/cf948rq56631k5dgzn62fkjm0000gn/T/ipykernel_11473/1581826677.py:4: DtypeWarning: Columns (2,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path,  delimiter='\t', header=None, names=[ 'c{0:02d}'.format(i) for i in range(10) ])

# %%
pred_01 = pd.read_csv("pred_20221030145821.log", names=["index", "date", "fuzzy", "sample", "pairwise",  "trend", "burst_mode", "entropy_mode", "pred_traffic", "pred_container", "max_cpu_usage"])
pred_01
# Out:
#     index                        date     fuzzy    sample  pairwise  \
# 0       0  2022-10-30T14:58:21.617660  1.542914       inf  0.225214
# 1       0  2022-10-30T14:58:36.537503  1.638199       inf  0.397919
# 2       0  2022-10-30T14:58:51.764777  1.515785  2.397895  0.515575
# 3       0  2022-10-30T14:59:06.694543  1.444373  1.504077  0.548308
# 4       0  2022-10-30T14:59:21.680377  1.682445       inf  0.524758
# ..    ...                         ...       ...       ...       ...
# 68      0  2022-10-30T15:15:27.355003  1.607035       inf -0.461453
# 69      0  2022-10-30T15:15:42.495122  1.718788       inf -0.315252
# 70      0  2022-10-30T15:15:57.373966  1.693066  2.397895 -0.459833
# 71      0  2022-10-30T15:16:16.550962  1.618268  2.708050 -0.463008
# 72      0  2022-10-30T15:16:27.161786  1.618268  2.708050 -0.463008
#
#          trend      burst_mode          entropy_mode  pred_traffic  \
# 0     Trend.Up  BurstMode.POOR  EntropyMode.EXPECTED    538.275862
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 4))
ln1 = axes[0].plot(simulation_log_date_02, simulation_log_count_02,label='baseline')

ax1 = axes[0].twinx()
ln2 = ax1.plot([datetime.fromisoformat(date_str) + timedelta(hours=9) for date_str in  pred_01["date"]], pred_01["pred_container"], color='green', label="cluster_size")

h1, l1 = axes[0].get_legend_handles_labels()
h2, l2 = ax1.get_legend_handles_labels()
axes[0].legend(h1+h2, l1+l2, loc='upper left')

axes[0].grid(True)

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 4))
ln1 = axes[0].plot(simulation_log_date_02, simulation_log_count_02,label='baseline')
ln1 = axes[0].plot([datetime.fromisoformat(date_str) + timedelta(hours=9) + timedelta(seconds=15) for date_str in  pred_01["date"]], pred_01["pred_traffic"].apply(lambda x: 0 if x < 0 else x ),label='predict')

ax1 = axes[0].twinx()
ln2 = ax1.plot([datetime.fromisoformat(date_str) + timedelta(hours=9) for date_str in  pred_01["date"]], pred_01["sample"], color='red', label="sample")

h1, l1 = axes[0].get_legend_handles_labels()
h2, l2 = ax1.get_legend_handles_labels()
axes[0].legend(h1+h2, l1+l2, loc='upper left')

axes[0].grid(True)

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 4))
ln1 = axes[0].plot(simulation_log_date_02, simulation_log_count_02,label='baseline')
ln1 = axes[0].plot([datetime.fromisoformat(date_str) + timedelta(hours=9) + timedelta(seconds=15) for date_str in  pred_01["date"]], pred_01["pred_traffic"].apply(lambda x: 0 if x < 0 else x ),label='predict')

ax1 = axes[0].twinx()
ln2 = ax1.plot([datetime.fromisoformat(date_str) + timedelta(hours=9) for date_str in  pred_01["date"]], pred_01["fuzzy"], color='blue', label="fuzzy")

h1, l1 = axes[0].get_legend_handles_labels()
h2, l2 = ax1.get_legend_handles_labels()
axes[0].legend(h1+h2, l1+l2, loc='upper left')

axes[0].grid(True)

# %%
def fuzzy_loop(ser: List[float], delay=1, dimension=2, batch_size = 50) -> List[float]:
    return [nk.entropy_fuzzy(np.array(ser[index-batch_size:index]), delay=delay, dimension=dimension)[0] for index in range(len(ser))[batch_size:]]

# %%
def sampen_loop(ser: List[float], batch_size = 50) -> List[float]:
    return [nk.entropy_sample(np.array(ser[index-batch_size:index]))[0] for index in range(len(ser))[batch_size:]]

# %%
fuzzy_simulation_log_count_02_delay_1 = fuzzy_loop(simulation_log_count_02, delay=10)

# %%
plt.plot(fuzzy_simulation_log_count_02_delay_1)

# %%
fuzzy_simulation_log_count_02_delay_2 = fuzzy_loop(simulation_log_count_02, dimension=3)

# %%
plt.plot(fuzzy_simulation_log_count_02_delay_1)
plt.plot(fuzzy_simulation_log_count_02_delay_2)

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 4))
ln1 = axes[0].plot(simulation_log_date_02, simulation_log_count_02,label='baseline')
ln1 = axes[0].plot([datetime.fromisoformat(date_str) + timedelta(hours=9) + timedelta(seconds=15) for date_str in  pred_01["date"]], pred_01["pred_traffic"].apply(lambda x: 0 if x < 0 else x ),label='predict')

ax1 = axes[0].twinx()
ln2 = ax1.plot([datetime.fromisoformat(date_str) + timedelta(hours=9) for date_str in  pred_01["date"]], pred_01["fuzzy"], color='blue', label="fuzzy")

h1, l1 = axes[0].get_legend_handles_labels()
h2, l2 = ax1.get_legend_handles_labels()
axes[0].legend(h1+h2, l1+l2, loc='upper left')

axes[0].grid(True)

# %%
signal_01 = nk.signal_simulate(duration=1, sampling_rate=1000, frequency=5, noise=0.1)
plt.plot(signal_01)

# %%
fuzzy_signal_01 = fuzzy_loop(signal_01)

# %%
plt.plot(fuzzy_signal_01)

# %%
sampen_signal_01 = sampen_loop(signal_01, batch_size=100)
plt.plot(sampen_signal_01)

# %%
sampen_signal_01
# Out:
# [1.8325814637483102,
#  2.197224577336219,
#  2.5649493574615363,
#  2.159484249353372,
#  2.079441541679836,
#  2.03688192726104,
#  2.079441541679836,
#  2.03688192726104,
#  1.9924301646902063,
#  1.9924301646902063,
#  1.9924301646902063,
#  1.9924301646902063,
#  2.03688192726104,
#  2.03688192726104,
#  2.120263536200091,
#  2.120263536200091,
#  2.197224577336219,
#  2.1972245773362196,
#  2.197224577336219,
#  2.3978952727983702,
#  2.3978952727983707,
#  2.2512917986064953,
#  1.845826690498331,
#  2.70805020110221,
#  2.6390573296152584,
#  2.772588722239781,
#  2.70805020110221,
#  2.6390573296152584,
#  2.6390573296152584,
#  2.70805020110221,
#  2.772588722239781,
#  inf,
#  inf,
#  2.6390573296152584,
#  2.772588722239781,
#  2.70805020110221,
#  2.70805020110221,
#  2.772588722239781,
#  2.5649493574615363,
#  2.4849066497880004,
#  2.5649493574615363,
#  2.5649493574615363,
#  2.5649493574615363,
#  2.4849066497880004,
#  2.4849066497880004,
#  1.791759469228055,
# ...
