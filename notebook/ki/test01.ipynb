# %%
import html2text

# %%
h = html2text.HTML2Text()

# %%
print (h.handle("<p>Hello, <a href='https://www.google.com/earth/'>world</a>!"))
# Out:
# Hello, [world](https://www.google.com/earth/)!

# %%
with open("./関数一覧 _ その他.html") as f:
        print(h.handle(f.read()))
# Out:
# [_KIシリーズ_
# 操作ガイド](https://ki.keyence.co.jp/data/lesson/html_manual_keyence/2.2.0/jp/index.html)
#
# **2.2.0** 操作ガイド
#
#   * [用語集・索引](https://ki.keyence.co.jp/data/lesson/html_manual_keyence/2.2.0/jp/glossary/index.html)
#   * [FAQ](https://info-analytics.keyence.com/cs/ss-faq-redirect)
#
# [![KI DATA ANALYTICS PLATFORM](./関数一覧 _
# その他_files/logo-2lines.svg)](https://ki.keyence.co.jp/)
#
#   * [はじめに](https://ki.keyence.co.jp/data/lesson/html_manual_keyence/2.2.0/jp/operation-manual/introduction/about.html)
#
#     * [はじめに](https://ki.keyence.co.jp/data/lesson/html_manual_keyence/2.2.0/jp/operation-manual/introduction/about.html)
#     * [機能概要](https://ki.keyence.co.jp/data/lesson/html_manual_keyence/2.2.0/jp/operation-manual/introduction/overview.html)
#     * [ログイン](https://ki.keyence.co.jp/data/lesson/html_manual_keyence/2.2.0/jp/operation-manual/introduction/login.html)
#
# ...
